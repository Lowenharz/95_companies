# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pprint import pprint
import plotly.graph_objects as go

# %%
percent_change_monthly_2 =  pd.read_csv('./NASDQ_or_NYSE_percent_change_Monthly_1999_base.csv')

# %%
f = open('./stock_ticker.txt','r')
file_list = f.readlines()
NYSE_or_NASDAQ = ['^GSPC']
for line in file_list: 
    splited_line =line.split(':') 
    if splited_line[0] in ['NYSE', 'NASDAQ']:
        NYSE_or_NASDAQ.append(splited_line[1].strip())

NYSE_or_NASDAQ.remove('LNKD')

# %%
percent_change_monthly_2 =  pd.read_csv('./NASDQ_or_NYSE_percent_change_Monthly_1999_base.csv',index_col = 0)
# pprint(percent_change_monthly_2_all)
percent_change_monthly_2_sin_SNP= percent_change_monthly_2.drop('^GSPC',axis =1)
# pprint(percent_change_monthly_2_sin_SNP)
percent_change_monthly_2_sin_SNP = percent_change_monthly_2_sin_SNP
# mean = percent_change_monthly_2_sin_SNP.mean(axis = 0, skipna = True)
percent_change_monthly_2_sin_SNP['mean'] = percent_change_monthly_2_sin_SNP.mean(axis=1)
# pprint(percent_change_monthly_2_sin_SNP)
result = percent_change_monthly_2['^GSPC']
# pprint(percent_change_monthly_2_sin_SNP['mean'])
percent_change_monthly_aggregate = percent_change_monthly_2_sin_SNP['mean']
result = pd.concat([result, percent_change_monthly_aggregate], axis=1, sort=False)
result.to_csv('./NASDQ_or_NYSE_aggregate_percent.csv')
# pprint(result)

# %%
result =  pd.read_csv('./NASDQ_or_NYSE_aggregate_percent.csv')
result.columns = ['Date', 'SNP 500', 'Aggregated_Ethical_Mean']
pprint(result)
# Out:
#            Date   SNP 500  Aggregated_Ethical_Mean
# 0    1999-01-31  1.000000                 1.000000
# 1    1999-02-28  0.998244                 0.979615
# 2    1999-03-31  1.026337                 0.983902
# 3    1999-04-30  1.068853                 1.029479
# 4    1999-05-31  1.066705                 1.075736
# ..          ...       ...                      ...
# 236  2018-09-30  2.323478                 5.260546
# 237  2018-10-31  2.230558                 4.969632
# 238  2018-11-30  2.180723                 4.931944
# 239  2018-12-31  2.055861                 4.726786
# 240  2019-01-31  2.009994                 4.625969
#
# [241 rows x 3 columns]

# %%
fig = go.Figure()

stocks = result.columns[1:]
# print(stocks)
for stock in stocks: 
    fig.add_trace(go.Scatter(x=result['Date'], y=result[stock],
                            mode='lines',
                            name=stock))

fig.show()
# Out:
# <div>
#
#
#             <div id="a8632e13-c68b-4997-8efa-6a22538c15ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a8632e13-c68b-4997-8efa-6a22538c15ac")) {
#                     Plotly.newPlot(
#                         'a8632e13-c68b-4997-8efa-6a22538c15ac',
#                         [{"mode": "lines", "name": "SNP 500", "type": "scatter", "x": ["1999-01-31", "1999-02-28", "1999-03-31", "1999-04-30", "1999-05-31", "1999-06-30", "1999-07-31", "1999-08-31", "1999-09-30", "1999-10-31", "1999-11-30", "1999-12-31", "2000-01-31", "2000-02-29", "2000-03-31", "2000-04-30", "2000-05-31", "2000-06-30", "2000-07-31", "2000-08-31", "2000-09-30", "2000-10-31", "2000-11-30", "2000-12-31", "2001-01-31", "2001-02-28", "2001-03-31", "2001-04-30", "2001-05-31", "2001-06-30", "2001-07-31", "2001-08-31", "2001-09-30", "2001-10-31", "2001-11-30", "2001-12-31", "2002-01-31", "2002-02-28", "2002-03-31", "2002-04-30", "2002-05-31", "2002-06-30", "2002-07-31", "2002-08-31", "2002-09-30", "2002-10-31", "2002-11-30", "2002-12-31", "2003-01-31", "2003-02-28", "2003-03-31", "2003-04-30", "2003-05