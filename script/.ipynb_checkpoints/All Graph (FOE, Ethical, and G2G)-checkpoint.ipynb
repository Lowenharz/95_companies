# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pprint import pprint
import plotly.graph_objects as go

# %%
G2G =  pd.read_csv('./G2G_aggregate_percent.csv',index_col = 0)
# G2G.columns = ['Date', 'SNP 500', 'Aggregated_G2G_Mean']
pprint(G2G)
ETHICAL =  pd.read_csv('./NASDQ_or_NYSE_aggregate_percent.csv',index_col = 0)
# ETHICAL.columns = ['Date', 'SNP 500', 'Aggregated_Ethical_Mean']
pprint(ETHICAL)
FOE =  pd.read_csv('./FOE_aggregate_percent.csv',index_col = 0)
# FOE.columns = ['Date', 'SNP 500', 'Aggregated_FOE_Mean']
# pprint(FOE)
# Out:
#                ^GSPC      mean
# Date
# 1999-01-31  0.000000  0.000000
# 1999-02-28 -0.001756  0.005274
# 1999-03-31  0.026337  0.010314
# 1999-04-30  0.068853  0.047389
# 1999-05-31  0.066705  0.043814
# 1999-06-30  0.059080 -0.000295
# 1999-07-31  0.105876  0.026578
# 1999-08-31  0.063033 -0.017893
# 1999-09-30  0.055572 -0.033201
# 1999-10-31  0.041028 -0.054564
# 1999-11-30  0.113894  0.009685
# 1999-12-31  0.144069 -0.019006
# 2000-01-31  0.141587 -0.052327
# 2000-02-29  0.112190 -0.111278
# 2000-03-31  0.154902 -0.176645
# 2000-04-30  0.170231 -0.115532
# 2000-05-31  0.135897 -0.124556
# 2000-06-30  0.170715 -0.144779
# 2000-07-31  0.179558 -0.137964
# 2000-08-31  0.189533 -0.116879
# 2000-09-30  0.175596 -0.086779
# 2000-10-31  0.113206 -0.053557
# 2000-11-30  0.101109  0.012371
# 2000-12-31  0.065788  0.041323
# 2001-01-31  0.069560  0.002872
# 2001-02-28  0.045626  0.052306
# 2001-03-31 -0.050389  0.026553
# 2001-04-30 -0.047196 -0.000178
# 2001-05-31  0.017292  0.033556
# 2001-06-30 -0.008059  0.035263
# ...              ...       ...
# 2016-08-31  0.743695  1.103328
# 2016-09-30  0.727846  1.040500
# 2016-10-31  0.716099  0.995003
# 2016-11-30  0.733688  1.090864
# 2016-12-31  0.799067  1.184540
# 2017-01-31  0.821879  1.173104
# 2017-02-28  0.865757  1.251182
# 2017-03-31  0.895316  1.269005
# 2017-04-30  0.889299  1.221915
# 2017-05-31  0.918157  1.199820
# 2017-06-30  0.949099  1.198440
# 2017-07-31  0.965208  1.186412
# 2017-08-31  0.966906  1.142333
# 2017-09-30  0.996230  1.127799
# 2017-10-31  1.047605  1.119183
# 2017-11-30  1.076920  1.096010
# 2017-12-31  1.133564  1.230185
# 2018-01-31  1.234033  1.350833
# 2018-02-28  1.166248  1.234472
# 2018-03-31  1.164341  1.178906
# 2018-04-30  1.124983  1.077596
# 2018-05-31  1.163315  1.064164
# 2018-06-30  1.205644  1.114498
# 2018-07-31  1.237108  1.160704
# 2018-08-31  1.288500  1.214578
# 2018-09-30  1.323478  1.216989
# 2018-10-31  1.230558  1.180973
# 2018-11-30  1.180723  1.261170
# 2018-12-31  1.055861  1.125599
# 2019-01-31  1.009994  1.032505
#
# [241 rows x 2 columns]
#                ^GSPC      mean
# Date
# 1999-01-31  0.000000  0.000000
# 1999-02-28 -0.001756 -0.020385
# 1999-03-31  0.026337 -0.016098
# 1999-04-30  0.068853  0.029479
# 1999-05-31  0.066705  0.075736
# 1999-06-30  0.059080  0.086537
# 1999-07-31  0.105876  0.125874
# 1999-08-31  0.063033  0.096061
# 1999-09-30  0.055572  0.068937
# 1999-10-31  0.041028  0.038292
# 1999-11-30  0.113894  0.091567
# 1999-12-31  0.144069  0.121577
# 2000-01-31  0.141587  0.142383
# 2000-02-29  0.112190  0.118592
# 2000-03-31  0.154902  0.138320
# 2000-04-30  0.170231  0.195451
# 2000-05-31  0.135897  0.184904
# 2000-06-30  0.170715  0.203149
# 2000-07-31  0.179558  0.221620
# 2000-08-31  0.189533  0.216110
# 2000-09-30  0.175596  0.202404
# 2000-10-31  0.113206  0.143984
# 2000-11-30  0.101109  0.173623
# 2000-12-31  0.065788  0.170147
# 2001-01-31  0.069560  0.186081
# 2001-02-28  0.045626  0.180655
# 2001-03-31 -0.050389  0.124265
# 2001-04-30 -0.047196  0.113576
# 2001-05-31  0.017292  0.196422
# 2001-06-30 -0.008059  0.178956
# ...              ...       ...
# 2016-08-31  0.743695  2.761821
# 2016-09-30  0.727846  2.744326
# 2016-10-31  0.716099  2.735926
# 2016-11-30  0.733688  2.745092
# 2016-12-31  0.799067  2.841318
# 2017-01-31  0.821879  2.931977
# 2017-02-28  0.865757  3.042035
# 2017-03-31  0.895316  3.122837
# 2017-04-30  0.889299  3.131491
# 2017-05-31  0.918157  3.266205
# 2017-06-30  0.949099  3.380865
# 2017-07-31  0.965208  3.453086
# 2017-08-31  0.966906  3.450511
# 2017-09-30  0.996230  3.542525
# 2017-10-31  1.047605  3.679743
# 2017-11-30  1.076920  3.721238
# 2017-12-31  1.133564  3.876492
# 2018-01-31  1.234033  4.081524
# 2018-02-28  1.166248  3.987015
# 2018-03-31  1.164341  4.055093
# 2018-04-30  1.124983  3.967830
# 2018-05-31  1.163315  3.929339
# 2018-06-30  1.205644  4.061346
# 2018-07-31  1.237108  4.092906
# 2018-08-31  1.288500  4.112256
# 2018-09-30  1.323478  4.260546
# 2018-10-31  1.230558  3.969632
# 2018-11-30  1.180723  3.931944
# 2018-12-31  1.055861  3.726786
# 2019-01-31  1.009994  3.625969
#
# [241 rows x 2 columns]

# %%
result = pd.concat([G2G, ETHICAL['mean'],FOE['mean']], axis=1, sort=False)
result.columns = ['SNP 500', 'Aggregated_G2G_Mean', 'Aggregated_ETHICAL_Mean','Aggregated_FOE_Mean']
# result.to_csv('./All_aggregate_percent.csv')
# result =  pd.read_csv('./All_aggregate_percent.csv')
print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-06f857d7d949> in <module>
#       1 result = pd.concat([G2G, ETHICAL['mean']], axis=1, sort=False)
# ----> 2 result.columns = ['SNP 500', 'Aggregated_G2G_Mean', 'Aggregated_ETHICAL_Mean','Aggregated_FOE_Mean']
#       3 # result.to_csv('./All_aggregate_percent.csv')
#       4 # result =  pd.read_csv('./All_aggregate_percent.csv')
#       5 print(result)
#
# F:\Program Files\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5078         try:
#    5079             object.__getattribute__(self, name)
# -> 5080             return object.__setattr__(self, name, value)
#    5081         except AttributeError:
#    5082             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# F:\Program Files\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     636
#     637     def _set_axis(self, axis, labels):
# --> 638         self._data.set_axis(axis, labels)
#     639         self._clear_item_cache()
#     640
#
# F:\Program Files\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     153             raise ValueError(
#     154                 'Length mismatch: Expected axis has {old} elements, new '
# --> 155                 'values have {new} elements'.format(old=old_len, new=new_len))
#     156
#     157         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 3 elements, new values have 4 elements

# %%
# pprint(result)
fig = go.Figure()

stocks = result.columns[1:]
# print(stocks)
for stock in stocks: 
    fig.add_trace(go.Scatter(x=result['Date'], y=result[stock],
                            mode='lines',
                            name=stock))

fig.show()
